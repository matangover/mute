# %%
import mute
import music21

# %%
example1 = music21.converter.parse("examples/example1.musicxml")
example1.show()

# %%
example2 = music21.converter.parse("examples/example2.musicxml")
example2.show()

# %%
mute.eval_phrase(example1, example2)
# Out:
# {'f1_score_pitch': 0.6074999999999999,
#  'f1_score_pitchclass': 0.6961904761904762,
#  'f1_score_mean_hands': 0.5791666666666666,
#  'f1_scores_per_hand': {'left': 0.6333333333333333, 'right': 0.525},
#  'added_bar_count': 1,
#  'removed_bar_count': 0,
#  'aligned_bar_count': 5,
#  'ref_bar_count': 4,
#  'target_bar_count': 5}

# %%
mute.eval_phrase(example1, example2, show=True)
# Out:
# {'f1_score_pitch': 0.6074999999999999,
#  'f1_score_pitchclass': 0.6961904761904762,
#  'f1_score_mean_hands': 0.5791666666666666,
#  'f1_scores_per_hand': {'left': 0.6333333333333333, 'right': 0.525},
#  'added_bar_count': 1,
#  'removed_bar_count': 0,
#  'aligned_bar_count': 5,
#  'ref_bar_count': 4,
#  'target_bar_count': 5}
